# %%
# import necessary modules from keras
from keras.layers import Dense,Softmax
from keras.models import Sequential

# creates a generic neural network architecture
model = Sequential()

# hidden layer takes a pre-processed frame as input, and has 200 units
model.add(Dense(units=200,input_dim=80*80, activation='relu', kernel_initializer='glorot_uniform'))
model.add(Dense(units=20,activation='relu', kernel_initializer='glorot_uniform'))
# model.add(Dense(units=200,input_dim=200, activation='relu', kernel_initializer='glorot_uniform'))



# output layer
model.add(Dense(units=1, activation='sigmoid', kernel_initializer='RandomNormal'))
# model.add(Softmax())

# compile the model using traditional Machine Learning losses and optimizers
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
import numpy as np
import gym
from gym import wrappers

# gym initialization
env = gym.make("Pong-v0")
env = wrappers.Monitor(env, 'tmp/pong-base', force=True)
observation = env.reset()
prev_input = None

# Macros
UP_ACTION = 2
DOWN_ACTION = 3
STOP = 0
act_space = {0:2,1:3,2:0}
# Hyperparameters
gamma = 0.99

# initialization of variables used in the main loop
x_train, y_train, rewards = [],[],[]
reward_sum = 0
episode_nb = 0

# %%
from karpathy import prepro, discount_rewards

# main loop
while (True):
    env.render()
    # preprocess the observation, set input as difference between images
    cur_input = prepro(observation)
    x = cur_input - prev_input if prev_input is not None else np.zeros(80 * 80)
    prev_input = cur_input
    
    # forward the policy network and sample action according to the proba distribution
    proba = model.predict(np.expand_dims(x, axis=1).T)
    action = UP_ACTION if np.random.uniform() < proba else DOWN_ACTION
    y = 1 if action == 2 else 0 # 0 and 1 are our labels

    # log the input and label to train later
    x_train.append(x)
    y_train.append(y)

    # do one step in our environment
    observation, reward, done, info = env.step(action)
    rewards.append(reward)
    reward_sum += reward
    
    # end of an episode
    if done:
        print('At the end of episode', episode_nb, 'the total reward was :', reward_sum)
        
        # increment episode number
        episode_nb += 1
        
        # training
        model.fit(x=np.vstack(x_train), y=np.vstack(y_train), verbose=1, sample_weight=discount_rewards(rewards, gamma))
                                                             
        # Reinitialization
        x_train, y_train, rewards = [],[],[]
        observation = env.reset()
        reward_sum = 0
        prev_input = None

# main loop
# while (True):
#     env.render()
#     # preprocess the observation, set input as difference between images
#     cur_input = prepro(observation)
#     x = cur_input - prev_input if prev_input is not None else np.zeros(80 * 80)
#     prev_input = cur_input
    
#     # forward the policy network and sample action according to the proba distribution
#     proba = model.predict(np.expand_dims(x, axis=1).T)
#     proba = np.squeeze(proba,axis=0)
#     act_label = np.argmax(proba)
    
# #     print(len(proba), proba[act_label])
#     act_label_min = np.argmin(proba)
#     action = 0
#     if np.random.uniform() < proba[act_label]:
#         action = act_space[act_label] 
#     else:
#         if np.random.uniform() < proba[act_label_min]/(np.sum(proba)-proba[act_label]):
#             action = act_space[act_label_min] 
#         else:
#             res = list(set(act_space)-set([act_label,act_label_min]))[0]
#             action = act_space[res] 
#     y = np.zeros(3)
#     y[act_label] = 1 # if action == 2 else 0 # 0 and 1 are our labels

#     # log the input and label to train later
#     x_train.append(x)
#     y_train.append(y)

#     # do one step in our environment
#     observation, reward, done, info = env.step(action)
#     rewards.append(reward)
#     reward_sum += reward
    
#     # end of an episode
#     if done:
#         print('At the end of episode', episode_nb, 'the total reward was :', reward_sum)
        
#         # increment episode number
#         episode_nb += 1
        
#         # training
#         model.fit(x=np.vstack(x_train), y=np.vstack(y_train), verbose=1, sample_weight=discount_rewards(rewards, gamma))
                                                             
#         # Reinitialization
#         x_train, y_train, rewards = [],[],[]
#         observation = env.reset()
#         reward_sum = 0
#         prev_input = None
# Out:
# At the end of episode 0 the total reward was : -21.0
# 40/40 [==============================] - 1s 6ms/step - loss: -2.0426e-04 - accuracy: 0.4952
# At the end of episode 1 the total reward was : -18.0
# 56/56 [==============================] - 0s 4ms/step - loss: 7.3456e-04 - accuracy: 0.5008
# At the end of episode 2 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 8.5644e-04 - accuracy: 0.5101
# At the end of episode 3 the total reward was : -19.0
# 47/47 [==============================] - 0s 3ms/step - loss: -7.2152e-04 - accuracy: 0.5241
# At the end of episode 4 the total reward was : -20.0
# 49/49 [==============================] - 0s 3ms/step - loss: 8.0778e-05 - accuracy: 0.5633
# At the end of episode 5 the total reward was : -20.0
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 0.5426
# At the end of episode 6 the total reward was : -21.0
# 40/40 [==============================] - 0s 4ms/step - loss: -0.0030 - accuracy: 0.5170
# At the end of episode 7 the total reward was : -21.0
# 45/45 [==============================] - 0s 4ms/step - loss: -0.0061 - accuracy: 0.5178
# At the end of episode 8 the total reward was : -20.0
# 49/49 [==============================] - 0s 5ms/step - loss: -0.0046 - accuracy: 0.5531
# At the end of episode 9 the total reward was : -21.0
# 38/38 [==============================] - 0s 6ms/step - loss: -0.0169 - accuracy: 0.5812
# At the end of episode 10 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0173 - accuracy: 0.6444
# At the end of episode 11 the total reward was : -21.0
# 40/40 [==============================] - 0s 4ms/step - loss: -0.0036 - accuracy: 0.6378
# At the end of episode 12 the total reward was : -21.0
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.6624
# At the end of episode 13 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0318 - accuracy: 0.6661
# At the end of episode 14 the total reward was : -21.0
# 43/43 [==============================] - 0s 3ms/step - loss: 2.7321e-04 - accuracy: 0.6588
# At the end of episode 15 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.6871
# At the end of episode 16 the total reward was : -21.0
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.6836
# At the end of episode 17 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.6682
# At the end of episode 18 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0101 - accuracy: 0.6679
# At the end of episode 19 the total reward was : -21.0
# 43/43 [==============================] - 0s 5ms/step - loss: -0.0155 - accuracy: 0.7033
# At the end of episode 20 the total reward was : -21.0
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.7448
# At the end of episode 21 the total reward was : -21.0
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0358 - accuracy: 0.7268
# At the end of episode 22 the total reward was : -21.0
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.7095
# At the end of episode 23 the total reward was : -21.0
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 0.6771
# At the end of episode 24 the total reward was : -21.0
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.6689
# At the end of episode 25 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.7209
# At the end of episode 26 the total reward was : -21.0
# 45/45 [==============================] - 0s 5ms/step - loss: -4.2403e-04 - accuracy: 0.6781
# At the end of episode 27 the total reward was : -21.0
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.6737
# At the end of episode 28 the total reward was : -20.0
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.6225
# At the end of episode 29 the total reward was : -20.0
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.6114
# At the end of episode 30 the total reward was : -21.0
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 0.6160
# At the end of episode 31 the total reward was : -21.0
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.5995
# At the end of episode 32 the total reward was : -20.0
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 0.6039
# At the end of episode 33 the total reward was : -20.0
# 43/43 [==============================] - 0s 3ms/step - loss: -0.0031 - accuracy: 0.5759
# At the end of episode 34 the total reward was : -20.0
# 39/39 [==============================] - 0s 5ms/step - loss: 9.1932e-04 - accuracy: 0.5936
# At the end of episode 35 the total reward was : -18.0
# 49/49 [==============================] - 0s 4ms/step - loss: -0.0065 - accuracy: 0.6304
# At the end of episode 36 the total reward was : -21.0
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 0.6185
# At the end of episode 37 the total reward was : -21.0
# 33/33 [==============================] - 0s 4ms/step - loss: -0.0083 - accuracy: 0.6176
# At the end of episode 38 the total reward was : -21.0
# 32/32 [==============================] - 0s 4ms/step - loss: -0.0074 - accuracy: 0.6456
# At the end of episode 39 the total reward was : -21.0
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 0.6538
# At the end of episode 40 the total reward was : -21.0
# 39/39 [==============================] - 0s 5ms/step - loss: -0.0176 - accuracy: 0.6656
# At the end of episode 41 the total reward was : -21.0
# 40/40 [==============================] - 0s 7ms/step - loss: -0.0115 - accuracy: 0.6622
# At the end of episode 42 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.6751
# At the end of episode 43 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.6718
# At the end of episode 44 the total reward was : -21.0
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.6779
# At the end of episode 45 the total reward was : -20.0
# 38/38 [==============================] - 0s 4ms/step - loss: -0.0121 - accuracy: 0.6455
# At the end of episode 46 the total reward was : -21.0
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.6468
# At the end of episode 47 the total reward was : -21.0
# 43/43 [==============================] - 0s 3ms/step - loss: -0.0094 - accuracy: 0.6179
# At the end of episode 48 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0078 - accuracy: 0.6484
# At the end of episode 49 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0019 - accuracy: 0.6633
# At the end of episode 50 the total reward was : -21.0
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.6570
# At the end of episode 51 the total reward was : -20.0
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.6391
# At the end of episode 52 the total reward was : -21.0
# 40/40 [==============================] - 0s 4ms/step - loss: -0.0140 - accuracy: 0.6800
# At the end of episode 53 the total reward was : -21.0
# 43/43 [==============================] - 0s 3ms/step - loss: -0.0517 - accuracy: 0.6841
# At the end of episode 54 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 0.7652
# At the end of episode 55 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 0.8020
# At the end of episode 56 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 0.8272
# At the end of episode 57 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.8053
# At the end of episode 58 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 0.8091
# At the end of episode 59 the total reward was : -21.0
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.8115
# At the end of episode 60 the total reward was : -21.0
# 37/37 [==============================] - 0s 4ms/step - loss: -0.0201 - accuracy: 0.7591
# At the end of episode 61 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.7866
# At the end of episode 62 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.7733
# At the end of episode 63 the total reward was : -21.0
# 46/46 [==============================] - 0s 5ms/step - loss: -0.0146 - accuracy: 0.7866
# At the end of episode 64 the total reward was : -21.0
# 35/35 [==============================] - 0s 6ms/step - loss: -0.0031 - accuracy: 0.7932
# At the end of episode 65 the total reward was : -21.0
# 37/37 [==============================] - 0s 4ms/step - loss: -0.0063 - accuracy: 0.8060
# At the end of episode 66 the total reward was : -21.0
# 38/38 [==============================] - 0s 6ms/step - loss: -0.0083 - accuracy: 0.8189
# At the end of episode 67 the total reward was : -21.0
# 34/34 [==============================] - 0s 5ms/step - loss: -0.0108 - accuracy: 0.8236
# At the end of episode 68 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0293 - accuracy: 0.8342
# At the end of episode 69 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: -0.0175 - accuracy: 0.8405
# At the end of episode 70 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 0.8659
# At the end of episode 71 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 0.8504
# At the end of episode 72 the total reward was : -21.0
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 0.8597
# At the end of episode 73 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.8625
# At the end of episode 74 the total reward was : -21.0
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 0.8720
# At the end of episode 75 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0025 - accuracy: 0.8526
# At the end of episode 76 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 0.8457
# At the end of episode 77 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0271 - accuracy: 0.8532
# At the end of episode 78 the total reward was : -21.0
# 45/45 [==============================] - 0s 3ms/step - loss: -0.0210 - accuracy: 0.8780
# At the end of episode 79 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0135 - accuracy: 0.8747
# At the end of episode 80 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 0.8949
# At the end of episode 81 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 0.9189
# At the end of episode 82 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0349 - accuracy: 0.8992
# At the end of episode 83 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 0.8895
# At the end of episode 84 the total reward was : -21.0
# 39/39 [==============================] - 0s 3ms/step - loss: -0.0054 - accuracy: 0.9073
# At the end of episode 85 the total reward was : -21.0
# 60/60 [==============================] - 0s 3ms/step - loss: -0.0335 - accuracy: 0.9017
# At the end of episode 86 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 0.9158
# At the end of episode 87 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.9273
# At the end of episode 88 the total reward was : -21.0
# 50/50 [==============================] - 0s 4ms/step - loss: -0.0113 - accuracy: 0.9248
# At the end of episode 89 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0019 - accuracy: 0.9284
# At the end of episode 90 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 0.9148
# At the end of episode 91 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0158 - accuracy: 0.9203
# At the end of episode 92 the total reward was : -21.0
# 58/58 [==============================] - 0s 3ms/step - loss: -0.0431 - accuracy: 0.9120
# At the end of episode 93 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 0.9355
# At the end of episode 94 the total reward was : -21.0
# 43/43 [==============================] - 0s 3ms/step - loss: -0.0348 - accuracy: 0.9396
# At the end of episode 95 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9528
# At the end of episode 96 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -3.7367e-04 - accuracy: 0.9510
# At the end of episode 97 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0193 - accuracy: 0.9634
# At the end of episode 98 the total reward was : -21.0
# 46/46 [==============================] - 0s 3ms/step - loss: -0.0017 - accuracy: 0.9716
# At the end of episode 99 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 0.9514
# At the end of episode 100 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 0.9473
# At the end of episode 101 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9364
# At the end of episode 102 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 0.9500
# At the end of episode 103 the total reward was : -21.0
# 55/55 [==============================] - 0s 3ms/step - loss: -0.0249 - accuracy: 0.9462
# At the end of episode 104 the total reward was : -21.0
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.9615
# At the end of episode 105 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0052 - accuracy: 0.9529
# At the end of episode 106 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9601
# At the end of episode 107 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -8.2736e-04 - accuracy: 0.9633
# At the end of episode 108 the total reward was : -21.0
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 0.9735
# At the end of episode 109 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9617
# At the end of episode 110 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0103 - accuracy: 0.9618
# At the end of episode 111 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0042 - accuracy: 0.9644
# At the end of episode 112 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 0.9607
# At the end of episode 113 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 0.9691
# At the end of episode 114 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9617
# At the end of episode 115 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0056 - accuracy: 0.9756
# At the end of episode 116 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 0.9733
# At the end of episode 117 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 0.9643
# At the end of episode 118 the total reward was : -21.0
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 0.9616
# At the end of episode 119 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 0.9680
# At the end of episode 120 the total reward was : -21.0
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 0.9724
# At the end of episode 121 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.9707
# At the end of episode 122 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 0.9689
# At the end of episode 123 the total reward was : -21.0
# 42/42 [==============================] - 0s 3ms/step - loss: 6.5049e-04 - accuracy: 0.9693
# At the end of episode 124 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -1.3585e-04 - accuracy: 0.9606
# At the end of episode 125 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9616
# At the end of episode 126 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 0.9564
# At the end of episode 127 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0025 - accuracy: 0.9648
# At the end of episode 128 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 0.9661
# At the end of episode 129 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 0.9675
# At the end of episode 130 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 0.9665
# At the end of episode 131 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0141 - accuracy: 0.9510
# At the end of episode 132 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0058 - accuracy: 0.9746
# At the end of episode 133 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9701
# At the end of episode 134 the total reward was : -21.0
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 0.9714
# At the end of episode 135 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9670
# At the end of episode 136 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9564
# At the end of episode 137 the total reward was : -21.0
# 37/37 [==============================] - 0s 5ms/step - loss: -0.0048 - accuracy: 0.9695
# At the end of episode 138 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9668
# At the end of episode 139 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 0.9664
# At the end of episode 140 the total reward was : -21.0
# 47/47 [==============================] - 0s 5ms/step - loss: -0.0170 - accuracy: 0.9688
# At the end of episode 141 the total reward was : -21.0
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9613
# At the end of episode 142 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0306 - accuracy: 0.9489
# At the end of episode 143 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9591
# At the end of episode 144 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9533
# At the end of episode 145 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 0.9492
# At the end of episode 146 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9403
# At the end of episode 147 the total reward was : -21.0
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9518
# At the end of episode 148 the total reward was : -21.0
# 40/40 [==============================] - 0s 5ms/step - loss: 3.5254e-04 - accuracy: 0.9587
# At the end of episode 149 the total reward was : -21.0
# 41/41 [==============================] - 0s 5ms/step - loss: -0.0037 - accuracy: 0.9532
# At the end of episode 150 the total reward was : -21.0
# 38/38 [==============================] - 0s 5ms/step - loss: -0.0129 - accuracy: 0.9523
# At the end of episode 151 the total reward was : -21.0
# 38/38 [==============================] - 0s 5ms/step - loss: 3.4721e-04 - accuracy: 0.9566
# At the end of episode 152 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0053 - accuracy: 0.9653
# At the end of episode 153 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 0.9543
# At the end of episode 154 the total reward was : -21.0
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9659
# At the end of episode 155 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9511
# At the end of episode 156 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9404
# At the end of episode 157 the total reward was : -21.0
# 42/42 [==============================] - 0s 5ms/step - loss: -0.0175 - accuracy: 0.9442
# At the end of episode 158 the total reward was : -21.0
# 38/38 [==============================] - 0s 5ms/step - loss: -0.0065 - accuracy: 0.9454
# At the end of episode 159 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9459
# At the end of episode 160 the total reward was : -21.0
# 42/42 [==============================] - 0s 5ms/step - loss: -0.0249 - accuracy: 0.9487
# At the end of episode 161 the total reward was : -21.0
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9568
# At the end of episode 162 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9447
# At the end of episode 163 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 0.9462
# At the end of episode 164 the total reward was : -21.0
# 50/50 [==============================] - 0s 5ms/step - loss: -0.0140 - accuracy: 0.9581
# At the end of episode 165 the total reward was : -21.0
# 42/42 [==============================] - 0s 5ms/step - loss: 3.9333e-04 - accuracy: 0.9572
# At the end of episode 166 the total reward was : -21.0
# 42/42 [==============================] - 0s 5ms/step - loss: -0.0061 - accuracy: 0.9499
# At the end of episode 167 the total reward was : -21.0
# 43/43 [==============================] - 0s 5ms/step - loss: -0.0159 - accuracy: 0.9429
# At the end of episode 168 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: -0.0069 - accuracy: 0.9505
# At the end of episode 169 the total reward was : -21.0
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 0.9520
# At the end of episode 170 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 0.9405
# At the end of episode 171 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: -0.0038 - accuracy: 0.9592
# At the end of episode 172 the total reward was : -21.0
# 38/38 [==============================] - 0s 5ms/step - loss: -0.0045 - accuracy: 0.9519
# At the end of episode 173 the total reward was : -21.0
# 37/37 [==============================] - 0s 5ms/step - loss: -0.0070 - accuracy: 0.9484
# At the end of episode 174 the total reward was : -21.0
# 48/48 [==============================] - 0s 5ms/step - loss: -0.0133 - accuracy: 0.9591
# At the end of episode 175 the total reward was : -21.0
# 37/37 [==============================] - 0s 5ms/step - loss: -0.0107 - accuracy: 0.9670
# At the end of episode 176 the total reward was : -21.0
# 34/34 [==============================] - 0s 5ms/step - loss: -0.0071 - accuracy: 0.9770
# At the end of episode 177 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 0.9730
# At the end of episode 178 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 7.8323e-04 - accuracy: 0.9737
# At the end of episode 179 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0088 - accuracy: 0.9753
# At the end of episode 180 the total reward was : -21.0
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9710
# At the end of episode 181 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9737
# At the end of episode 182 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0078 - accuracy: 0.9755
# At the end of episode 183 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0141 - accuracy: 0.9746
# At the end of episode 184 the total reward was : -21.0
# 37/37 [==============================] - 0s 4ms/step - loss: -0.0024 - accuracy: 0.9772
# At the end of episode 185 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 0.9703
# At the end of episode 186 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0038 - accuracy: 0.9724
# At the end of episode 187 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9652
# At the end of episode 188 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0194 - accuracy: 0.9599
# At the end of episode 189 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0019 - accuracy: 0.9575
# At the end of episode 190 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0135 - accuracy: 0.9706
# At the end of episode 191 the total reward was : -21.0
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9584
# At the end of episode 192 the total reward was : -21.0
# 37/37 [==============================] - 0s 4ms/step - loss: -0.0105 - accuracy: 0.9611
# At the end of episode 193 the total reward was : -21.0
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 0.9614
# At the end of episode 194 the total reward was : -21.0
# 63/63 [==============================] - 0s 3ms/step - loss: -0.0238 - accuracy: 0.9701
# At the end of episode 195 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0134 - accuracy: 0.9664
# At the end of episode 196 the total reward was : -21.0
# 45/45 [==============================] - 0s 3ms/step - loss: -0.0187 - accuracy: 0.9593
# At the end of episode 197 the total reward was : -21.0
# 34/34 [==============================] - 0s 3ms/step - loss: -0.0054 - accuracy: 0.9658
# At the end of episode 198 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 0.9513
# At the end of episode 199 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0132 - accuracy: 0.9449
# At the end of episode 200 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0075 - accuracy: 0.9686
# At the end of episode 201 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0095 - accuracy: 0.9734
# At the end of episode 202 the total reward was : -21.0
# 50/50 [==============================] - 0s 3ms/step - loss: -0.0072 - accuracy: 0.9528
# At the end of episode 203 the total reward was : -21.0
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.9818
# At the end of episode 204 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0039 - accuracy: 0.9760
# At the end of episode 205 the total reward was : -21.0
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 0.9815
# At the end of episode 206 the total reward was : -21.0
# 46/46 [==============================] - 0s 3ms/step - loss: -0.0080 - accuracy: 0.9827
# At the end of episode 207 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 0.9754
# At the end of episode 208 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 0.9800
# At the end of episode 209 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.9864
# At the end of episode 210 the total reward was : -21.0
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9814
# At the end of episode 211 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.9827
# At the end of episode 212 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0037 - accuracy: 0.9810
# At the end of episode 213 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: -0.0107 - accuracy: 0.9741
# At the end of episode 214 the total reward was : -21.0
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9765
# At the end of episode 215 the total reward was : -21.0
# 55/55 [==============================] - 0s 3ms/step - loss: -0.0058 - accuracy: 0.9742
# At the end of episode 216 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.9848
# At the end of episode 217 the total reward was : -21.0
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 0.9769
# At the end of episode 218 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0130 - accuracy: 0.9793
# At the end of episode 219 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0051 - accuracy: 0.9715
# At the end of episode 220 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 0.9780
# At the end of episode 221 the total reward was : -21.0
# 34/34 [==============================] - 0s 3ms/step - loss: -0.0022 - accuracy: 0.9770
# At the end of episode 222 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9712
# At the end of episode 223 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9754
# At the end of episode 224 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0148 - accuracy: 0.9782
# At the end of episode 225 the total reward was : -21.0
# 50/50 [==============================] - 0s 3ms/step - loss: -0.0180 - accuracy: 0.9711
# At the end of episode 226 the total reward was : -21.0
# 34/34 [==============================] - 1s 24ms/step - loss: -0.0228 - accuracy: 0.9558
# At the end of episode 227 the total reward was : -21.0
# 42/42 [==============================] - 0s 5ms/step - loss: -0.0029 - accuracy: 0.9582
# At the end of episode 228 the total reward was : -20.0
# 44/44 [==============================] - 0s 4ms/step - loss: -0.0176 - accuracy: 0.9523
# At the end of episode 229 the total reward was : -20.0
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 0.9518
# At the end of episode 230 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0542 - accuracy: 0.9567
# At the end of episode 231 the total reward was : -20.0
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 0.9354
# At the end of episode 232 the total reward was : -21.0
# 40/40 [==============================] - 0s 5ms/step - loss: -0.0043 - accuracy: 0.9451
# At the end of episode 233 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 0.9315
# At the end of episode 234 the total reward was : -20.0
# 39/39 [==============================] - 1s 26ms/step - loss: 0.0029 - accuracy: 0.9537
# At the end of episode 235 the total reward was : -21.0
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9509
# At the end of episode 236 the total reward was : -21.0
# 45/45 [==============================] - 0s 6ms/step - loss: -0.0036 - accuracy: 0.9637
# At the end of episode 237 the total reward was : -21.0
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0294 - accuracy: 0.9712
# At the end of episode 238 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 0.9632
# At the end of episode 239 the total reward was : -21.0
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 0.9582
# At the end of episode 240 the total reward was : -20.0
# 55/55 [==============================] - 0s 3ms/step - loss: -0.0073 - accuracy: 0.9567
# At the end of episode 241 the total reward was : -21.0
# 55/55 [==============================] - 0s 3ms/step - loss: -0.0014 - accuracy: 0.9604
# At the end of episode 242 the total reward was : -21.0
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 0.9762
# At the end of episode 243 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 0.9529
# At the end of episode 244 the total reward was : -21.0
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0459 - accuracy: 0.9597
# At the end of episode 245 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 0.9728
# At the end of episode 246 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.9652
# At the end of episode 247 the total reward was : -21.0
# 45/45 [==============================] - 0s 3ms/step - loss: -0.0035 - accuracy: 0.9662
# At the end of episode 248 the total reward was : -21.0
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9649
# At the end of episode 249 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 0.9736
# At the end of episode 250 the total reward was : -21.0
# 63/63 [==============================] - 0s 3ms/step - loss: -0.0154 - accuracy: 0.9695
# At the end of episode 251 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 0.9729
# At the end of episode 252 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9640
# At the end of episode 253 the total reward was : -20.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.9715
# At the end of episode 254 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.9753
# At the end of episode 255 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0278 - accuracy: 0.9612
# At the end of episode 256 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0085 - accuracy: 0.9679
# At the end of episode 257 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 0.9543
# At the end of episode 258 the total reward was : -21.0
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 0.9697
# At the end of episode 259 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -1.7914e-04 - accuracy: 0.9515
# At the end of episode 260 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0048 - accuracy: 0.9582
# At the end of episode 261 the total reward was : -20.0
# 49/49 [==============================] - 0s 3ms/step - loss: -0.0023 - accuracy: 0.9676
# At the end of episode 262 the total reward was : -18.0
# 67/67 [==============================] - 0s 3ms/step - loss: -0.0029 - accuracy: 0.9587
# At the end of episode 263 the total reward was : -21.0
# 53/53 [==============================] - 0s 3ms/step - loss: -0.0026 - accuracy: 0.9643
# At the end of episode 264 the total reward was : -20.0
# 42/42 [==============================] - 0s 3ms/step - loss: -0.0014 - accuracy: 0.9605
# At the end of episode 265 the total reward was : -20.0
# 41/41 [==============================] - 0s 3ms/step - loss: -0.0013 - accuracy: 0.9618
# At the end of episode 266 the total reward was : -18.0
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 0.9528
# At the end of episode 267 the total reward was : -21.0
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 0.9527
# At the end of episode 268 the total reward was : -19.0
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9697
# At the end of episode 269 the total reward was : -21.0
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9455
# At the end of episode 270 the total reward was : -20.0
# 51/51 [==============================] - 0s 5ms/step - loss: -0.0076 - accuracy: 0.9409
# At the end of episode 271 the total reward was : -19.0
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9701
# At the end of episode 272 the total reward was : -20.0
# 47/47 [==============================] - 0s 5ms/step - loss: -0.0060 - accuracy: 0.9689
# At the end of episode 273 the total reward was : -20.0
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 0.9791
# At the end of episode 274 the total reward was : -21.0
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9726
# At the end of episode 275 the total reward was : -21.0
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9659
# At the end of episode 276 the total reward was : -21.0
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0688e-04 - accuracy: 0.9692
# At the end of episode 277 the total reward was : -21.0
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 0.9577
# At the end of episode 278 the total reward was : -21.0
# 50/50 [==============================] - 0s 5ms/step - loss: -5.9993e-04 - accuracy: 0.9673
# At the end of episode 279 the total reward was : -21.0
# 52/52 [==============================] - 0s 5ms/step - loss: -0.0065 - accuracy: 0.9729
# At the end of episode 280 the total reward was : -21.0
# 53/53 [==============================] - 0s 5ms/step - loss: -0.0254 - accuracy: 0.9574
# At the end of episode 281 the total reward was : -20.0
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9584
# At the end of episode 282 the total reward was : -21.0
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9650
# At the end of episode 283 the total reward was : -21.0
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.9685
# At the end of episode 284 the total reward was : -20.0
# 59/59 [==============================] - 0s 5ms/step - loss: -0.0043 - accuracy: 0.9793
# At the end of episode 285 the total reward was : -20.0
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9820
# At the end of episode 286 the total reward was : -21.0
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9721
# At the end of episode 287 the total reward was : -21.0
# 50/50 [==============================] - 0s 5ms/step - loss: -0.0083 - accuracy: 0.9741
# At the end of episode 288 the total reward was : -19.0
# 47/47 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9619
# At the end of episode 289 the total reward was : -21.0
# 43/43 [==============================] - 0s 5ms/step - loss: -0.0169 - accuracy: 0.9673
# At the end of episode 290 the total reward was : -20.0
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 0.9711
# At the end of episode 291 the total reward was : -21.0
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.9795
# At the end of episode 292 the total reward was : -20.0
# 42/42 [==============================] - 0s 5ms/step - loss: -0.0015 - accuracy: 0.9635
# At the end of episode 293 the total reward was : -21.0
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9634
# At the end of episode 294 the total reward was : -19.0
# 50/50 [==============================] - 0s 5ms/step - loss: -0.0100 - accuracy: 0.9648
# At the end of episode 295 the total reward was : -20.0
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 0.9728
# At the end of episode 296 the total reward was : -19.0
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.9710
# At the end of episode 297 the total reward was : -20.0
# 44/44 [==============================] - 0s 5ms/step - loss: -0.0081 - accuracy: 0.9707
# At the end of episode 298 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9686
# At the end of episode 299 the total reward was : -21.0
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9617
# At the end of episode 300 the total reward was : -20.0
# 56/56 [==============================] - 0s 3ms/step - loss: -0.0134 - accuracy: 0.9642
# At the end of episode 301 the total reward was : -18.0
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9686
# At the end of episode 302 the total reward was : -21.0
# 48/48 [==============================] - 0s 7ms/step - loss: -0.0474 - accuracy: 0.9587
# At the end of episode 303 the total reward was : -21.0
# 53/53 [==============================] - 0s 6ms/step - loss: -0.0279 - accuracy: 0.9690
# At the end of episode 304 the total reward was : -20.0
# 44/44 [==============================] - 0s 6ms/step - loss: -0.0048 - accuracy: 0.9669
# At the end of episode 305 the total reward was : -20.0
# 49/49 [==============================] - 0s 6ms/step - loss: 2.1452e-04 - accuracy: 0.9755
# At the end of episode 306 the total reward was : -21.0
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9784
# At the end of episode 307 the total reward was : -19.0
# 48/48 [==============================] - 0s 6ms/step - loss: -0.0046 - accuracy: 0.9749
# At the end of episode 308 the total reward was : -20.0
# 59/59 [==============================] - 0s 5ms/step - loss: -9.3117e-04 - accuracy: 0.9667
# At the end of episode 309 the total reward was : -20.0
# 64/64 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9746
# At the end of episode 310 the total reward was : -21.0
# 48/48 [==============================] - 0s 6ms/step - loss: -0.0020 - accuracy: 0.9756
# At the end of episode 311 the total reward was : -20.0
# 41/41 [==============================] - 0s 7ms/step - loss: -0.0025 - accuracy: 0.9816
# At the end of episode 312 the total reward was : -20.0
# 49/49 [==============================] - 0s 6ms/step - loss: -0.0105 - accuracy: 0.9646
# At the end of episode 313 the total reward was : -19.0
# 52/52 [==============================] - 0s 6ms/step - loss: -0.0063 - accuracy: 0.9688
# At the end of episode 314 the total reward was : -21.0
# 37/37 [==============================] - 0s 6ms/step - loss: -0.0133 - accuracy: 0.9762
# At the end of episode 315 the total reward was : -21.0
# 38/38 [==============================] - 0s 7ms/step - loss: -0.0136 - accuracy: 0.9679
# At the end of episode 316 the total reward was : -21.0
# 45/45 [==============================] - 0s 7ms/step - loss: -0.0173 - accuracy: 0.9718
# At the end of episode 317 the total reward was : -19.0
# 55/55 [==============================] - 0s 6ms/step - loss: -0.0087 - accuracy: 0.9718
# At the end of episode 318 the total reward was : -21.0
# 40/40 [==============================] - 0s 6ms/step - loss: -0.0064 - accuracy: 0.9749
# At the end of episode 319 the total reward was : -21.0
# 37/37 [==============================] - 0s 6ms/step - loss: -0.0141 - accuracy: 0.9674
# At the end of episode 320 the total reward was : -21.0
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9716
# At the end of episode 321 the total reward was : -21.0
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9834
# At the end of episode 322 the total reward was : -21.0
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 0.9735
# At the end of episode 323 the total reward was : -21.0
# 35/35 [==============================] - 0s 6ms/step - loss: -0.0184 - accuracy: 0.9753
# At the end of episode 324 the total reward was : -12.0
# 79/79 [==============================] - 0s 5ms/step - loss: -0.0034 - accuracy: 0.9700
# At the end of episode 325 the total reward was : -21.0
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0175 - accuracy: 0.9779
# At the end of episode 326 the total reward was : -21.0
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0203 - accuracy: 0.9782
# At the end of episode 327 the total reward was : -21.0
# 32/32 [==============================] - 0s 6ms/step - loss: -8.1348e-04 - accuracy: 0.9814
# At the end of episode 328 the total reward was : -20.0
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0106 - accuracy: 0.9634
# At the end of episode 329 the total reward was : -21.0
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9735
# At the end of episode 330 the total reward was : -19.0
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0186 - accuracy: 0.9698
# At the end of episode 331 the total reward was : -21.0
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9809
# At the end of episode 332 the total reward was : -21.0
# 32/32 [==============================] - 0s 6ms/step - loss: -0.0079 - accuracy: 0.9813
# At the end of episode 333 the total reward was : -20.0
# 46/46 [==============================] - 0s 6ms/step - loss: -0.0075 - accuracy: 0.9730
# At the end of episode 334 the total reward was : -21.0
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 0.9738
# At the end of episode 335 the total reward was : -20.0
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 0.9733
# At the end of episode 336 the total reward was : -21.0
# 40/40 [==============================] - 0s 4ms/step - loss: -0.0088 - accuracy: 0.9844
# ...
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0031 - accuracy: 0.9973
# At the end of episode 1082 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0357 - accuracy: 0.9897
# At the end of episode 1083 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 8.7909e-04 - accuracy: 0.9920
# At the end of episode 1084 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -9.0581e-04 - accuracy: 0.9941
# At the end of episode 1085 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0052 - accuracy: 0.9949
# At the end of episode 1086 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -2.2633e-04 - accuracy: 1.0000
# At the end of episode 1087 the total reward was : -21.0
# 46/46 [==============================] - 0s 3ms/step - loss: -0.0103 - accuracy: 0.9958
# At the end of episode 1088 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.9953
# At the end of episode 1089 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 0.9955
# At the end of episode 1090 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0198 - accuracy: 0.9957
# At the end of episode 1091 the total reward was : -20.0
# 39/39 [==============================] - 0s 3ms/step - loss: 2.6301e-04 - accuracy: 0.9975
# At the end of episode 1092 the total reward was : -20.0
# 39/39 [==============================] - 0s 3ms/step - loss: 1.2055e-04 - accuracy: 0.9975
# At the end of episode 1093 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0055 - accuracy: 0.9973
# At the end of episode 1094 the total reward was : -21.0
# 43/43 [==============================] - 0s 3ms/step - loss: -0.0015 - accuracy: 0.9985
# At the end of episode 1095 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 0.9960
# At the end of episode 1096 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 2.6861e-04 - accuracy: 0.9982
# At the end of episode 1097 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0023 - accuracy: 0.9957
# At the end of episode 1098 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0035 - accuracy: 0.9955
# At the end of episode 1099 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 0.9964
# At the end of episode 1100 the total reward was : -21.0
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 0.9933
# At the end of episode 1101 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0115 - accuracy: 0.9945
# At the end of episode 1102 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 0.9973
# At the end of episode 1103 the total reward was : -20.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0024 - accuracy: 0.9976
# At the end of episode 1104 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0059 - accuracy: 0.9941
# At the end of episode 1105 the total reward was : -20.0
# 41/41 [==============================] - 0s 3ms/step - loss: -0.0055 - accuracy: 0.9946
# At the end of episode 1106 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0021 - accuracy: 0.9975
# At the end of episode 1107 the total reward was : -20.0
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 0.9980
# At the end of episode 1108 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9960
# At the end of episode 1109 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9945
# At the end of episode 1110 the total reward was : -21.0
# 45/45 [==============================] - 0s 3ms/step - loss: -0.0030 - accuracy: 0.9958
# At the end of episode 1111 the total reward was : -20.0
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.9950
# At the end of episode 1112 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0032 - accuracy: 0.9941
# At the end of episode 1113 the total reward was : -21.0
# 35/35 [==============================] - 0s 4ms/step - loss: -9.7721e-04 - accuracy: 0.9982
# At the end of episode 1114 the total reward was : -21.0
# 55/55 [==============================] - 0s 3ms/step - loss: 3.4362e-06 - accuracy: 0.9960
# At the end of episode 1115 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9991
# At the end of episode 1116 the total reward was : -20.0
# 46/46 [==============================] - 0s 3ms/step - loss: -2.8815e-04 - accuracy: 0.9959
# At the end of episode 1117 the total reward was : -20.0
# 41/41 [==============================] - 0s 3ms/step - loss: -0.0043 - accuracy: 0.9946
# At the end of episode 1118 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0056 - accuracy: 0.9945
# At the end of episode 1119 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0116 - accuracy: 0.9915
# At the end of episode 1120 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 0.9928
# At the end of episode 1121 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0219 - accuracy: 0.9898
# At the end of episode 1122 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 0.9945
# At the end of episode 1123 the total reward was : -21.0
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9916
# At the end of episode 1124 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9983
# At the end of episode 1125 the total reward was : -21.0
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 0.9928
# At the end of episode 1126 the total reward was : -21.0
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 0.9987
# At the end of episode 1127 the total reward was : -21.0
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 0.9968
# At the end of episode 1128 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0061 - accuracy: 0.9976
# At the end of episode 1129 the total reward was : -20.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0056 - accuracy: 0.9952
# At the end of episode 1130 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 4.6243e-04 - accuracy: 0.9966
# At the end of episode 1131 the total reward was : -21.0
# 40/40 [==============================] - 0s 4ms/step - loss: -0.0061 - accuracy: 0.9968
# At the end of episode 1132 the total reward was : -20.0
# 37/37 [==============================] - 0s 3ms/step - loss: 4.8879e-04 - accuracy: 0.9957
# At the end of episode 1133 the total reward was : -21.0
# 39/39 [==============================] - 0s 3ms/step - loss: -0.0017 - accuracy: 0.9976
# At the end of episode 1134 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0106 - accuracy: 0.9954
# At the end of episode 1135 the total reward was : -20.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0054 - accuracy: 0.9942
# At the end of episode 1136 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0185 - accuracy: 0.9918
# At the end of episode 1137 the total reward was : -20.0
# 51/51 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9883
# At the end of episode 1138 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 7.2788e-04 - accuracy: 0.9982
# At the end of episode 1139 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0159 - accuracy: 0.9932
# At the end of episode 1140 the total reward was : -21.0
# 48/48 [==============================] - 0s 3ms/step - loss: -0.0046 - accuracy: 0.9947
# At the end of episode 1141 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0020 - accuracy: 0.9973
# At the end of episode 1142 the total reward was : -20.0
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.9900
# At the end of episode 1143 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -5.7342e-04 - accuracy: 0.9974
# At the end of episode 1144 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0239 - accuracy: 0.9941
# At the end of episode 1145 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 0.9936
# At the end of episode 1146 the total reward was : -20.0
# 36/36 [==============================] - 0s 4ms/step - loss: -8.3291e-04 - accuracy: 0.9991
# At the end of episode 1147 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 0.9976
# At the end of episode 1148 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 0.9966
# At the end of episode 1149 the total reward was : -21.0
# 44/44 [==============================] - 0s 3ms/step - loss: 9.1955e-04 - accuracy: 0.9993
# At the end of episode 1150 the total reward was : -20.0
# 39/39 [==============================] - 0s 3ms/step - loss: -0.0021 - accuracy: 0.9968
# At the end of episode 1151 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0460 - accuracy: 0.9955
# At the end of episode 1152 the total reward was : -21.0
# 50/50 [==============================] - 0s 3ms/step - loss: -0.0112 - accuracy: 0.9962
# At the end of episode 1153 the total reward was : -20.0
# 36/36 [==============================] - 0s 3ms/step - loss: -1.6113e-04 - accuracy: 0.9947
# At the end of episode 1154 the total reward was : -20.0
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 0.9966
# At the end of episode 1155 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0200 - accuracy: 0.9933
# At the end of episode 1156 the total reward was : -21.0
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 0.9948
# At the end of episode 1157 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0064 - accuracy: 0.9936
# At the end of episode 1158 the total reward was : -21.0
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 0.9949
# At the end of episode 1159 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.9982
# At the end of episode 1160 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 0.9953
# At the end of episode 1161 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0012 - accuracy: 0.9976
# At the end of episode 1162 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 0.9992
# At the end of episode 1163 the total reward was : -21.0
# 34/34 [==============================] - 0s 3ms/step - loss: -0.0028 - accuracy: 0.9972
# At the end of episode 1164 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0016 - accuracy: 0.9984
# At the end of episode 1165 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 0.9991
# At the end of episode 1166 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -0.0037 - accuracy: 0.9976
# At the end of episode 1167 the total reward was : -21.0
# 50/50 [==============================] - 0s 3ms/step - loss: -0.0219 - accuracy: 0.9930
# At the end of episode 1168 the total reward was : -21.0
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0338 - accuracy: 0.9825
# At the end of episode 1169 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.1040 - accuracy: 0.9864
# At the end of episode 1170 the total reward was : -21.0
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9886
# At the end of episode 1171 the total reward was : -21.0
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 0.9915
# At the end of episode 1172 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 0.9946
# At the end of episode 1173 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0089 - accuracy: 0.9958
# At the end of episode 1174 the total reward was : -20.0
# 47/47 [==============================] - 0s 3ms/step - loss: -0.0054 - accuracy: 0.9893
# At the end of episode 1175 the total reward was : -20.0
# 41/41 [==============================] - 0s 3ms/step - loss: -8.3219e-05 - accuracy: 0.9954
# At the end of episode 1176 the total reward was : -20.0
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 0.9977
# At the end of episode 1177 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -7.1544e-04 - accuracy: 0.9983
# At the end of episode 1178 the total reward was : -21.0
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.9979
# At the end of episode 1179 the total reward was : -21.0
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# At the end of episode 1180 the total reward was : -21.0
# 58/58 [==============================] - 0s 3ms/step - loss: -0.0043 - accuracy: 0.9869
# At the end of episode 1181 the total reward was : -21.0
# 36/36 [==============================] - 0s 3ms/step - loss: -0.0012 - accuracy: 0.9964
# At the end of episode 1182 the total reward was : -21.0
# 47/47 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9960
# At the end of episode 1183 the total reward was : -21.0
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.9972
# At the end of episode 1184 the total reward was : -21.0
# 53/53 [==============================] - 0s 3ms/step - loss: -0.0033 - accuracy: 0.9958
# At the end of episode 1185 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 0.9945
# At the end of episode 1186 the total reward was : -21.0
# 40/40 [==============================] - 0s 3ms/step - loss: -2.4376e-04 - accuracy: 0.9976
# At the end of episode 1187 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0118 - accuracy: 0.9945
# At the end of episode 1188 the total reward was : -20.0
# 38/38 [==============================] - 0s 3ms/step - loss: -0.0093 - accuracy: 0.9926
# At the end of episode 1189 the total reward was : -21.0
# 35/35 [==============================] - 0s 3ms/step - loss: -0.0234 - accuracy: 0.9955
# At the end of episode 1190 the total reward was : -21.0
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.9975
# At the end of episode 1191 the total reward was : -21.0
# 37/37 [==============================] - 0s 3ms/step - loss: -0.0073 - accuracy: 0.9983
