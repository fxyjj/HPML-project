# %%
# import necessary modules from keras
from keras.layers import Dense,Softmax
from keras.layers import Conv2D,Flatten,MaxPooling2D
from keras.models import Sequential

# creates a generic neural network architecture
model = Sequential()

# hidden layer takes a pre-processed frame as input, and has 200 units
model.add(Conv2D(filters = 1,
                         kernel_size = 5,
                         strides = 1,
                         activation = 'relu',
                         input_shape = (80,80,1)))
model.add(MaxPooling2D(pool_size = 2, strides = 2))
model.add(Conv2D(filters = 1,
                         kernel_size = 5,
                         strides = 1,
                         activation = 'relu',
                         input_shape = (38,38,1)))
model.add(MaxPooling2D(pool_size = 2, strides = 2))
model.add(Conv2D(filters = 1,
                         kernel_size = 5,
                         strides = 1,
                         activation = 'relu',
                         input_shape = (17,17,1)))
model.add(Flatten())
model.add(Dense(units=200,activation='relu', kernel_initializer='glorot_uniform'))
# model.add(Dense(units=200,input_dim=200, activation='relu', kernel_initializer='glorot_uniform'))

# output layer
model.add(Dense(units=1, activation='sigmoid', kernel_initializer='RandomNormal'))
# model.add(Softmax())

# compile the model using traditional Machine Learning losses and optimizers
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
import numpy as np
import gym
from gym import wrappers

# gym initialization
env = gym.make("Pong-v0")
env = wrappers.Monitor(env, 'tmp/pong-base', force=True)
observation = env.reset()
prev_input = None

# Macros
UP_ACTION = 2
DOWN_ACTION = 3
STOP = 0
act_space = {0:2,1:3,2:0}
# Hyperparameters
gamma = 0.99

# initialization of variables used in the main loop
x_train, y_train, rewards = [],[],[]
reward_sum = 0
episode_nb = 0

# %%
from karpathy import prepro, discount_rewards

# main loop
while (True):
    env.render()
    # preprocess the observation, set input as difference between images
    cur_input = prepro(observation)
    x = cur_input - prev_input if prev_input is not None else np.zeros(80 * 80)
    x = np.resize(x,(80,80))
    x = np.expand_dims(x, axis=0).T
#     print(x.shape)
    prev_input = cur_input
    
    # forward the policy network and sample action according to the proba distribution
    proba = model.predict(np.expand_dims(x, axis=0).T)
    action = UP_ACTION if np.random.uniform() < proba else DOWN_ACTION
    y = 1 if action == 2 else 0 # 0 and 1 are our labels

    # log the input and label to train later
    x_train.append(x)
    y_train.append(y)

    # do one step in our environment
    observation, reward, done, info = env.step(action)
    rewards.append(reward)
    reward_sum += reward
    
    # end of an episode
    if done:
        print('At the end of episode', episode_nb, 'the total reward was :', reward_sum)
        
        # increment episode number
        episode_nb += 1
#         test=np.array(x_train)
#         testy = np.array(y_train)
#         print(test.shape,testy)
        
        # training
        model.fit(x=np.array(x_train), y=np.array(y_train), verbose=1, sample_weight=discount_rewards(rewards, gamma))
                                                             
        # Reinitialization
        x_train, y_train, rewards = [],[],[]
        observation = env.reset()
        reward_sum = 0
        prev_input = None
# Out:
# At the end of episode 0 the total reward was : -21.0
# 40/40 [==============================] - 2s 31ms/step - loss: -7.1341e-04 - accuracy: 0.4845
# At the end of episode 1 the total reward was : -20.0
# 49/49 [==============================] - 2s 35ms/step - loss: -4.2786e-06 - accuracy: 0.5238
# At the end of episode 2 the total reward was : -21.0
# 42/42 [==============================] - 1s 30ms/step - loss: -0.0012 - accuracy: 0.5097
# At the end of episode 3 the total reward was : -21.0
# 42/42 [==============================] - 1s 30ms/step - loss: -8.4564e-04 - accuracy: 0.5150
# At the end of episode 4 the total reward was : -21.0
# 37/37 [==============================] - 1s 30ms/step - loss: -0.0049 - accuracy: 0.5110
# At the end of episode 5 the total reward was : -20.0
# 47/47 [==============================] - 1s 30ms/step - loss: -0.0030 - accuracy: 0.4692
# At the end of episode 6 the total reward was : -21.0
# 32/32 [==============================] - 1s 29ms/step - loss: -0.0719 - accuracy: 0.4575
# At the end of episode 7 the total reward was : -21.0
# 35/35 [==============================] - 1s 30ms/step - loss: -3.9957 - accuracy: 0.3056
# At the end of episode 8 the total reward was : -21.0
# 32/32 [==============================] - 1s 31ms/step - loss: -2.3135e-18 - accuracy: 1.0000
# At the end of episode 9 the total reward was : -21.0
# 33/33 [==============================] - 1s 30ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 10 the total reward was : -21.0
# 32/32 [==============================] - 1s 29ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 11 the total reward was : -21.0
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 12 the total reward was : -21.0
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 13 the total reward was : -21.0
# 33/33 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 14 the total reward was : -21.0
# 33/33 [==============================] - 1s 30ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 15 the total reward was : -21.0
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 16 the total reward was : -21.0
# 33/33 [==============================] - 1s 30ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 17 the total reward was : -21.0
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 18 the total reward was : -21.0
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 19 the total reward was : -21.0
# 33/33 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 20 the total reward was : -21.0
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 21 the total reward was : -21.0
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 22 the total reward was : -21.0
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 23 the total reward was : -21.0
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# At the end of episode 24 the total reward was : -21.0
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c3fdbd1a1979> in <module>
#      13
#      14     # forward the policy network and sample action according to the proba distribution
# ---> 15     proba = model.predict(np.expand_dims(x, axis=0).T)
#      16     action = UP_ACTION if np.random.uniform() < proba else DOWN_ACTION
#      17     y = 1 if action == 2 else 0 # 0 and 1 are our labels
#
# ~/anaconda3/envs/mlHW/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/envs/mlHW/lib/python3.9/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1949               stacklevel=2)
#    1950
# -> 1951       data_handler = data_adapter.get_data_handler(
#    1952           x=x,
#    1953           batch_size=batch_size,
#
# ~/anaconda3/envs/mlHW/lib/python3.9/site-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1397   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1398     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1399   return DataHandler(*args, **kwargs)
#    1400
#    1401
#
# ~/anaconda3/envs/mlHW/lib/python3.9/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1147
#    1148     adapter_cls = select_data_adapter(x, y)
# -> 1149     self._adapter = adapter_cls(
#    1150         x,
#    1151         y,
#
# ~/anaconda3/envs/mlHW/lib/python3.9/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     326     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     327
# --> 328     dataset = self.slice_inputs(indices_dataset, inputs)
#     329
#     330     if shuffle == "batch":
#
# ~/anaconda3/envs/mlHW/lib/python3.9/site-packages/keras/engine/data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     358       return tf.nest.map_structure(lambda d: tf.gather(d, i, axis=0), data)
#     359
# --> 360     dataset = dataset.map(
#     361         grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     362
#
# ~/anaconda3/envs/mlHW/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic, name)
#    2016       return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2017     else:
# -> 2018       return ParallelMapDataset(
#    2019           self,
#    2020           map_func,
#
# ~/anaconda3/envs/mlHW/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5232     self._input_dataset = input_dataset
#    5233     self._use_inter_op_parallelism = use_inter_op_parallelism
# -> 5234     self._map_func = structured_function.StructuredFunctionWrapper(
#    5235         map_func,
#    5236         self._transformation_name(),
#
# ~/anaconda3/envs/mlHW/lib/python3.9/site-packages/tensorflow/python/data/ops/structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     269         fn_factory = trace_tf_function(defun_kwargs)
#     270
# --> 271     self._function = fn_factory()
#     272     # There is no graph to add in eager mode.
#     273     add_to_graph &= not context.executing_eagerly()
#
# ~/anaconda3/envs/mlHW/lib/python3.9/site-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3068          or `tf.Tensor` or `tf.TensorSpec`.
#    3069     """
# -> 3070     graph_function = self._get_concrete_function_garbage_collected(
#    3071         *args, **kwargs)
#    3072     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# ~/anaconda3/envs/mlHW/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3043       # pylint: enable=protected-access
#    3044       num_positional = 0
# -> 3045       for arg in graph_function.graph.inputs:
#    3046         if arg in captured:
#    3047           break
#
# KeyboardInterrupt:
